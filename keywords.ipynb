# %%
import pandas
from app.keywords import get_keywords
from app.graphs import radial_chart

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pandas.read_csv("data/data.csv")

# %%
df["keywords"] = df["text"].apply(get_keywords)

# %%
keys = df.drop(columns=["text"]).explode(column="keywords").dropna()

# %%
radial_chart("keywords", keys)
# Out:
# alt.LayerChart(...)
